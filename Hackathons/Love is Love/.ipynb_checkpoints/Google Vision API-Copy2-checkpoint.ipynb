# %% [markdown]
# ## Google Vision API
#
# Google Cloud’s Vision API offers powerful pre-trained machine learning models through REST and RPC APIs. Assign labels to images and quickly classify them into millions of predefined categories. Detect objects and faces, read printed and handwritten text, and build valuable metadata into your image catalog.
#
# ### Text
#
# __Text Detection__ performs Optical Character Recognition. It detects and extracts text within an image with support for a broad range of languages. It also features automatic language identification.

# %%
#Import the required libraries
import os
import cv2
import numpy as np
import pandas as pd

#Natural Language Processing libraries
from spacy.matcher import PhraseMatcher
import nltk
import re as re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#Using the client library

import io
import os

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types
os.environ['GOOGLE_APPLICATION_CREDENTIALS']= "loveislove-283821-212563ace637.json"
def detect_text(path):
    """Detects text in the file."""

# %%
#Install Vision API Client Library for Python
# !pip install google-cloud-vision
# Out:
# Requirement already satisfied: google-cloud-vision in c:\users\kanum\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-cloud-vision) (1.21.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.18.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.19.2)
# Requirement already satisfied: pytz in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2019.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.12.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (3.12.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.51.0)
# Requirement already satisfied: setuptools>=34.0.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (41.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2.22.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0; extra == "grpc" in c:\users\kanum\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.30.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in c:\users\kanum\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kanum\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kanum\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (0.2.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kanum\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kanum\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kanum\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kanum\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (3.0.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kanum\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2.0dev,>=1.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (0.4.8)

# %%
from google.cloud import vision

# %% [markdown]
# Before calling client we need to set environment or else we will get __DefaultCredentialsError__:
# Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started
# Using the above resource enabling the environment

# %%
#For example:

#$env:GOOGLE_APPLICATION_CREDENTIALS="C:\Users\username\Downloads\my-key.json"

#With command prompt:

#set GOOGLE_APPLICATION_CREDENTIALS=[PATH]

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="loveislove-283821-212563ace637.json"

# %%
#The next step is to call ImageAnnotatorClient() which contains the utilities for extracting image properties.
client = vision.ImageAnnotatorClient()

# %%
img = cv2.imread("Test803.jpg",'rb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-45ec0b6f8114> in <module>
# ----> 1 img = cv2.imread("Test803.jpg",'rb')
#
# TypeError: an integer is required (got type str)

# %%
path = "Test803.jpg"

# %%
import cv2

im = cv2.imread('Test803.jpg')
im_resize = cv2.resize(im, (500, 500))

is_success, im_buf_arr = cv2.imencode(".jpg", im_resize)
byte_im = im_buf_arr.tobytes()

# %%
byte_im
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x01\xf4\x01\xf4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xb5\xf3\x87\xb5\x1ep\xf6\xaa\xd4W\xe4\xdc\xc8\xf7\x0b>p\xf6\xa3\xce\x1e\xd5Z\x8a9\x90\x16|\xe1\xedG\x9c=\xaa\xb5\x14s ,\xf9\xc3\xda\x8f8{Uj(\xe6@Y\xf3\x87\xb5\x1ep\xf6\xaa\xd4Q\xcc\x80\xb3\xe7\x0fj<\xe1\xedU\xa8\xa3\x99\x01g\xce\x1e\xd4y\xc3\xda\xabQG2\x02\xcf\x9c=\xa8\xf3\x87\xb5V\xa2\x8ed\x05\x9f8{Q\xe7\x0fj\xadE\x1c\xc8\x0b>p\xf6\xa3\xce\x1e\xd5Z\x8a9\x90\x16|\xe1\xedG\x9c=\xaa\xb5\x14s ,\xf9\xc3\xda\x8f8{Uj(\xe6@Y\xf3\x87\xb5\x1ep\xf6\xaa\xd4Q\xcc\x80\xb3\xe7\x0fj<\xe1\xedU\xa8\xa3\x99\x01g\xce\x1e\xd4y\xc3\xda\xabQG2\x02\xcf\x9c=\xa8\xf3\x87\xb5V\xa2\x8ed\x05\x9f8{Q\xe7\x0fj\xadE\x1c\xc8\x0b>p\xf6\xa3\xce\x1e\xd5Z\x8a9\x90\x16|\xe1\xedG\x9c=\xaa\xb5\x14s ,\xf9\xc3\xda\x8f8{Uj(\xe6@Y\xf3\x87\xb5\x1ep\xf6\xaa\xd4Q\xcc\x80\xb3\xe7\x0fj<\xe1\xedU\xa8\xa3\x99\x01g\xce\x1e\xd4y\xc3\xda\xabQG2\x02\xcf\x9c=\xa8\xf3\x87\xb5V\xa2\x8ed\x05\x9f8{Q\xe7\x0fj\xadE\x1c\xc8\x0b>p\xf6\xa3\xce\x1e\xd5Z\x8a9\x90\x16|\xe1\xedG\x9c=\xaa\xb5\x14s ,\xf9\xc3\xda\x8f8{Uj(\xe6@Y\xf3\x87\xb5\x1ep\xf6\xaa\xd4Q\xcc\x80\xb3\xe7\x0fj<\xe1\xedU\xa8\xa3\x99\x01g\xce\x1e\xd4y\xc3\xda\xabQG2\x02\xcf\x9c=\xa8\xaa\xd4Q\xcc\x80~\xc5\xf4\xa3b\xfaR\xd1Ys\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-IG0\x11l_J6/\xa5KQ\xd1\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8d\x8b\xe9KE\x1c\xc0&\xc5\xf4\xa3b\xfaR\xd1G0\t\xb1}(\xd8\xbe\x94\xb4Q\xcc\x02l_J6/\xa5-\x14s\x00\x9b\x17\xd2\x8aZ(\xe6\x00\xa2\x8a++\xb0\n(\xa2\x8b\xb0\n(\xa2\x8b\xb0\n(\xa ...

# %%
import io

with io.open(img, 'rb') as image_file:
        content = image_file.read()

# %%
content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00\xa8\x00\xec\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf6\xcc\x9a2h\xa2\xbc\xab\x9b\x06M\x194QE\xc02h\xc9\xa2\x8a.\x01\x93FM\x14Qp\x0c\x9a2h\xcd\x14\\\x03&\x8c\x9a(\xa2\xe0\x194d\xd1E\x17\x00\xc9\xa3&\x8a(\xb8\x06M\x194QE\xc02h\xc9\xa2\x8a.\x01\x93FM\x14Qp\x0c\x9a2h\xa2\x8b\x80d\xd1\x93E\x14\\\x03&\x8c\x9a(\xa2\xe0\x194d\xd1E\x17\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa3p\xf5\xac\xddrsm\xa6H\xea\xe5\x0f\x00\x1a\xa7\x1e\x9f\x98\x92Y/%\xc3\x00ylVU\xeb\xc2\x8d\x9c\xfa\x94\xa2\xde\xa6\xed\x15\x80\xf1^Z\xa9\x96\xce\xe4\xcc\xab\xc9F9\xcdi\xe9\xba\x82_\xdb\xefQ\xb5\xc1\xc3)\xea\r:5\xa1Y^\x1f\xf0A\xc5\xa2\xed\x14\x94\xb9\xad\t\n(\xcd\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x00QE\x14\x01\x85\xe2\xc4/\xa1I\x8e\xcc\x0f\xebUu\t\x11l\xec|\xe2DG\x1b\xbf*\xd1\xf1\x12\x17\xd1g\x18\xe83O\xb5\x8d&\xd3\xe0\x12"\xb0\xd8:\x8a\xe1\xc7\xd5T\x9d9\xb5sX\xfc&~\x98\xa3\xfbFSj[\xec\xa5G^\x99\xac\xcdN\xee\xe6\xc3\xc4Q\xdb\xd8\xb2\xa7\xda\x17-\x91\xd0\x8a\xde\xbb\xd4-\xac#\xda\xb8.~\xeci\xd4\x9a\xe7\xe5\xb4\x9f\xfbF\xd6\xf6\xe8bYX\xe1\x7f\xba=+\x1a\x12\xa9)\xcf\x13nT\x93\xfc\x8b\x8d\xaf\xef\x17\x84\xda\xde\x7f\xe3\xea/\xfb\xe6\x9e\xda\x86\xb1\x11W\xc4R(\xea\x83\xa9\xa7\xdc\xdc\x0bx\xf72\xb3\x7f\xba3Y\xb2k\x8a\x9d-.\x1b\xe8\xb5\xc5O0\xc6\xce\xd2\x8d\xack\xec\xe2\xcb\xf6\xfe!\xba\x97[\x82\xceKo*9\x019\'\x9a\xe9\xab\x81\xd3\xaf\x1fS\xf1U\xab\x0bic\x11!$\xb8\xc5w\xd5\xf4\x14\xe5)R\x8c\xa6\xb5g=X\xa8\xca\xc8Z(\xa2\x99\x90QE\x14\xc0(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\xab_\\\xbd\xad\xa4\x93$fFQ\x9d\xa3\xbd\x16\xbb\xb0\x16h\xae8x\xc6\xe1\x86V\xcb?V\xad\r#\xc4\xd1\xdf\\\x1b{\x84\x10J~\xe8\'\x83G\xbb~^\xa6\x8e\x8dH\xaekht\x14U=KQ\x87L\xb3{\x99\x9b\xe5Q\xc0\xf5\xaef?\x19\xdc\xc8\x9b\xfe\xc3\x80ze\xa8zF\xec!NR\xd6(\xe9uu\r\xa5N\x0f\xf7j\x1bP\x1fL\x8dKm\x05\x00\xcddE\xad\xdcj\xbae\xe1{o-\x118l\xf54\xfb\xa7\x1f\xd8\x16\xc5\x98\xaa\x1d\xbb\x88=\xab\x830\xa7\xcf\xec\xe3~\xa5E5t\xc8\x97I\x93K\x99\xefm\xe47\x04\x1c\xb2\xc9\xc9\xc7\xb5K\xa8\xdd%\xe4\xba|\xc9\xd1\x89\xe3\xd2\xa6\xd3\x82\xfd\xb6D\xb7v{b\x9c\x969\x19\xacwb\x9a\xc0\x80\x7f\xabIN\xdf\xca\xa5Nj5h\xcd\xde\xd1\xd0\xa8\xab\xc93^y\xe1\xb7\x8f|\xce\x15}ME\x1d\xf5\ ...

# %%
#In the above step I have successfully loaded the image into the workspace
image = vision.types.Image(content = byte_im)

# %%
image
# Out:
# content: "\377\330\377\340\000\020JFIF\000\001\001\000\000\001\000\001\000\000\377\333\000C\000\002\001\001\001\001\001\002\001\001\001\002\002\002\002\002\004\003\002\002\002\002\005\004\004\003\004\006\005\006\006\006\005\006\006\006\007\t\010\006\007\t\007\006\006\010\013\010\t\n\n\n\n\n\006\010\013\014\013\n\014\t\n\n\n\377\333\000C\001\002\002\002\002\002\002\005\003\003\005\n\007\006\007\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\377\300\000\021\010\001\364\001\364\003\001\"\000\002\021\001\003\021\001\377\304\000\037\000\000\001\005\001\001\001\001\001\001\000\000\000\000\000\000\000\000\001\002\003\004\005\006\007\010\t\n\013\377\304\000\265\020\000\002\001\003\003\002\004\003\005\005\004\004\000\000\001}\001\002\003\000\004\021\005\022!1A\006\023Qa\007\"q\0242\201\221\241\010#B\261\301\025R\321\360$3br\202\t\n\026\027\030\031\032%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\203\204\205\206\207\210\211\212\222\223\224\225\226\227\230\231\232\242\243\244\245\246\247\250\251\252\262\263\264\265\266\267\270\271\272\302\303\304\305\306\307\310\311\312\322\323\324\325\326\327\330\331\332\341\342\343\344\345\346\347\350\351\352\361\362\363\364\365\366\367\370\371\372\377\304\000\037\001\000\003\001\001\001\001\001\001\001\001\001\000\000\000\000\000\000\001\002\003\004\005\006\007\010\t\n\013\377\304\000\265\021\000\002\001\002\004\004\003\004\007\005\004\004\000\001\002w\000\001\002\003\021\004\005!1\006\022AQ\007aq\023\"2\201\010\024B\221\241\261\301\t#3R\360\025br\321\n\026$4\341%\361\027\030\031\032&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\202\203\204\205\206\207\210\211\212\222\223\224\225\226\227\230\231\232\242\243\244\245\246\247\250\251\252\262\263\264\265\266\267\270\271\272\302\303\304\305\306\307\310\311\312\322\323\324\325\326\327\330\331\332\342\343\344\345\346\347\350\351\352\362\363\364\365\366\367\370\371\372\377\332\000\014\003\001\000\002\021\003\021\000?\000\375\265\363\207\265\036p\366\252\324W\344\334\310\367\013>p\366\243\316\036\325Z\2129\220\026|\341\355G\234=\252\265\024s ,\371\303\332\2178{Uj(\346@Y\363\207\265\036p\366\252\324Q\314\200\263\347\017j<\341\355U\250\243\231\001g\316\036\324y\303\332\253QG2\002\317\234=\250\363\207\265V\242\216d\005\2378{Q\347\017j\255E\034\310\013>p\366\243\316\036\325Z\2129\220\026|\341\355G\234=\252\265\024s ,\371\303\332\2178{Uj(\346@Y\363\207\265\036p\366\252\324Q\314\200\263\347\017j<\341\355U\250\243\231\001g\316\036\324y\303\332\253QG2\002\317\234=\250\363\207\265V\242\216d\005\2378{Q\347\017j\255E\034\310\013>p\366\243\316\036\325Z\2129\220\026|\341\355G\234=\252\265\024s ,\371\303\332\2178{Uj(\346@Y\363\207\265\036p\366\252\324Q\314\200\263\347\017j<\341\355U\250\243\231\001g\316\036\324y\303\332\253QG2\002\317\234=\250\363\207\265V\242\216d\005\2378{Q\347\017j\255E\034\310\013>p\366\243\316\036\325Z\2129\220\026|\341\355G\234=\252\265\024s ,\371\303\332\2178{Uj(\346@Y\363\207\265\036p\366\252\324Q\314\200\263\347\017j<\341\355U\250\243\231\001g\316\036\324y\303\332\253QG2\002\317\234=\250\252\324Q\314\200~\305\364\243b\372R\321Ys\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-\024s\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-IG0\021l_J6/\245KQ\321\314\002l_J6/\245-\024s\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-\024s\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-\024s\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-\024s\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-\024s\000\233\027\322\215\213\351KE\034\300&\305\364\243b\372R\321G0\t\261}(\330\276\224\264Q\314\002l_J6/\245-\024s\000\233\027\322\212Z(\346\000\242\212++\260\n(\242\213\260\n(\242\21 ...

# %%
response = client.text_detection(image=image)

# %%
response
# Out:
# text_annotations {
#   locale: "en"
#   description: "DURSH\nAn original y alvay\nworth more than a c\303\263py.\n"
#   bounding_poly {
#     vertices {
#       x: 25
#       y: 197
#     }
#     vertices {
#       x: 490
#       y: 197
#     }
#     vertices {
#       x: 490
#       y: 458
#     }
#     vertices {
#       x: 25
#       y: 458
#     }
#   }
# }
# text_annotations {
#   description: "DURSH"
#   bounding_poly {
#     vertices {
#       x: 30
#       y: 197
#     }
#     vertices {
#       x: 490
#       y: 214
#     }
#     vertices {
#       x: 485
#       y: 343
#     }
#     vertices {
#       x: 25
#       y: 326
#     }
#   }
# }
# text_annotations {
#   description: "An"
#   bounding_poly {
#     vertices {
#       x: 71
#       y: 342
#     }
#     vertices {
#       x: 127
#       y: 342
#     }
#     vertices {
#       x: 127
#       y: 410
#     }
#     vertices {
#       x: 71
#       y: 410
#     }
#   }
# }
# text_annotations {
#   description: "original"
#   bounding_poly {
#     vertices {
#       x: 137
#       y: 338
#     }
#     vertices {
#       x: 280
#       y: 339
#     }
#     vertices {
#       x: 280
#       y: 412
#     }
#     vertices {
#       x: 137
#       y: 411
#     }
#   }
# }
# text_annotations {
#   description: "y"
#   bounding_poly {
#     vertices {
#       x: 289
#       y: 347
#     }
#     vertices {
#       x: 311
#       y: 347
#     }
#     vertices {
#       x: 311
#       y: 398
#     }
#     vertices {
#       x: 289
#       y: 398
#     }
#   }
# }
# text_annotations {
#   description: "alvay"
#   bounding_poly {
#     vertices {
#       x: 326
#       y: 338
#     }
#     vertices {
#       x: 443
#       y: 339
#     }
#     vertices {
#       x: 443
#       y: 413
#     }
#     vertices {
#       x: 326
#       y: 412
#     }
#   }
# }
# text_annotations {
#   description: "worth"
#   bounding_poly {
#     vertices {
#       x: 32
#       y: 384
#     }
#     vertices {
#       x: 135
#       y: 388
#     }
#     vertices {
#       x: 133
#       y: 440
#     }
#     vertices {
#       x: 30
#       y: 436
#     }
#   }
# }
# text_annotations {
#   description: "more"
#   bounding_poly {
#     vertices {
#       x: 152
#       y: 389
#     }
#     vertices {
#       x: 233
#       y: 392
#     }
#     vertices {
#       x: 231
#       y: 437
#     }
#     vertices {
#       x: 150
#       y: 434
#     }
#   }
# }
# text_annotations {
#   description: "than"
#   bounding_poly {
#     vertices {
#       x: 252
#       y: 392
#     }
#     vertices {
#       x: 335
#       y: 395
#     }
#     vertices {
#       x: 333
#       y: 441
#     }
#     vertices {
#       x: 250
#       y: 438
#     }
#   }
# }
# text_annotations {
#   description: "a"
#   bounding_poly {
#     vertices {
#       x: 349
#       y: 412
#     }
#     vertices {
#       x: 372
#       y: 413
#     }
#     vertices {
#       x: 371
#       y: 434
#     }
#     vertices {
#       x: 348
#       y: 433
#     }
#   }
# }
# text_annotations {
#   description: "c\303\263py."
#   bounding_poly {
#     vertices {
#       x: 388
#       y: 398
#     }
#     vertices {
#       x: 473
#       y: 401
#     }
#     vertices {
#       x: 471
#       y: 458
#     }
#     vertices {
#       x: 386
#       y: 455
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 1.0
#       }
#     }
#     width: 500
#     height: 500
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 30
#           y: 197
#         }
#         vertices {
#           x: 490
#           y: 214
#         }
#         vertices {
#           x: 485
#           y: 343
#         }
#         vertices {
#           x: 25
#           y: 326
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 30
#             y: 197
#           }
#           vertices {
#             x: 490
#             y: 214
#           }
#           vertices {
#             x: 485
#             y: 343
#           }
#           vertices {
#             x: 25
#             y: 326
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 30
#               y: 197
#             }
#             vertices {
#               x: 490
#               y: 214
#             }
#             vertices {
#               x: 485
#               y: 343
#             }
#             vertices {
#               x: 25
#               y: 326
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 30
#                 y: 197
#               }
#               vertices {
#                 x: 191
#                 y: 203
#               }
#               vertices {
#                 x: 186
#                 y: 332
#               }
#               vertices {
#                 x: 25
#                 y: 326
#               }
#             }
#             text: "D"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 192
#                 y: 203
#               }
#               vertices {
#                 x: 234
#                 y: 205
#               }
#               vertices {
#                 x: 229
#                 y: 333
#               }
#               vertices {
#                 x: 187
#                 y: 332
#               }
#             }
#             text: "U"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 235
#                 y: 205
#               }
#               vertices {
#                 x: 278
#                 y: 207
#               }
#               vertices {
#                 x: 273
#                 y: 336
#               }
#               vertices {
#                 x: 230
#                 y: 334
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 279
#                 y: 206
#               }
#               vertices {
#                 x: 321
#                 y: 208
#               }
#               vertices {
#                 x: 316
#                 y: 336
#               }
#               vertices {
#                 x: 274
#                 y: 335
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 322
#                 y: 208
#               }
#               vertices {
#                 x: 490
#                 y: 214
#               }
#               vertices {
#                 x: 485
#                 y: 343
#               }
#               vertices {
#                 x: 317
#                 y: 337
#               }
#             }
#             text: "H"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 32
#           y: 329
#         }
#         vertices {
#           x: 474
#           y: 339
#         }
#         vertices {
#           x: 471
#           y: 458
#         }
#         vertices {
#           x: 29
#           y: 448
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 32
#             y: 329
#           }
#           vertices {
#             x: 474
#             y: 339
#           }
#           vertices {
#             x: 471
#             y: 458
#           }
#           vertices {
#             x: 29
#             y: 448
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 71
#               y: 342
#             }
#             vertices {
#               x: 127
#               y: 342
#             }
#             vertices {
#               x: 127
#               y: 410
#             }
#             vertices {
#               x: 71
#               y: 410
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 71
#                 y: 342
#               }
#               vertices {
#                 x: 114
#                 y: 342
#               }
#               vertices {
#                 x: 114
#                 y: 410
#               }
#               vertices {
#                 x: 71
#                 y: 410
#               }
#             }
#             text: "A"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 115
#                 y: 342
#               }
#               vertices {
#                 x: 127
#                 y: 342
#               }
#               vertices {
#                 x: 127
#                 y: 410
#               }
#               vertices {
#                 x: 115
#                 y: 410
#               }
#             }
#             text: "n"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 137
#               y: 338
#             }
#             vertices {
#               x: 280
#               y: 339
#             }
#             vertices {
#               x: 280
#               y: 412
#             }
#             vertices {
#               x: 137
#               y: 411
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 137
#                 y: 338
#               }
#               vertices {
#                 x: 166
#                 y: 338
#               }
#               vertices {
#                 x: 166
#                 y: 410
#               }
#               vertices {
#                 x: 137
#                 y: 410
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 167
#                 y: 339
#               }
#               vertices {
#                 x: 178
#                 y: 339
#               }
#               vertices {
#                 x: 178
#                 y: 411
#               }
#               vertices {
#                 x: 167
#                 y: 411
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 179
#                 y: 339
#               }
#               vertices {
#                 x: 191
#                 y: 339
#               }
#               vertices {
#                 x: 191
#                 y: 411
#               }
#               vertices {
#                 x: 179
#                 y: 411
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 192
#                 y: 339
#               }
#               vertices {
#                 x: 204
#                 y: 339
#               }
#               vertices {
#                 x: 204
#                 y: 411
#               }
#               vertices {
#                 x: 192
#                 y: 411
#               }
#             }
#             text: "g"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 205
#                 y: 339
#               }
#               vertices {
#                 x: 217
#                 y: 339
#               }
#               vertices {
#                 x: 217
#                 y: 411
#               }
#               vertices {
#                 x: 205
#                 y: 411
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 218
#                 y: 339
#               }
#               vertices {
#                 x: 243
#                 y: 339
#               }
#               vertices {
#                 x: 243
#                 y: 411
#               }
#               vertices {
#                 x: 218
#                 y: 411
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 244
#                 y: 339
#               }
#               vertices {
#                 x: 255
#                 y: 339
#               }
#               vertices {
#                 x: 255
#                 y: 411
#               }
#               vertices {
#                 x: 244
#                 y: 411
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 256
#                 y: 339
#               }
#               vertices {
#                 x: 280
#                 y: 339
#               }
#               vertices {
#                 x: 280
#                 y: 411
#               }
#               vertices {
#                 x: 256
#                 y: 411
#               }
#             }
#             text: "l"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 289
#               y: 347
#             }
#             vertices {
#               x: 311
#               y: 347
#             }
#             vertices {
#               x: 311
#               y: 398
#             }
#             vertices {
#               x: 289
#               y: 398
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 289
#                 y: 347
#               }
#               vertices {
#                 x: 311
#                 y: 347
#               }
#               vertices {
#                 x: 311
#                 y: 398
#               }
#               vertices {
#                 x: 289
#                 y: 398
#               }
#             }
#             text: "y"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 326
#               y: 338
#             }
#             vertices {
#               x: 443
#               y: 339
#             }
#             vertices {
#               x: 443
#               y: 413
#             }
#             vertices {
#               x: 326
#               y: 412
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 326
#                 y: 338
#               }
#               vertices {
#                 x: 345
#                 y: 338
#               }
#               vertices {
#                 x: 345
#                 y: 411
#               }
#               vertices {
#                 x: 326
#                 y: 411
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 346
#                 y: 338
#               }
#               vertices {
#                 x: 358
#                 y: 338
#               }
#               vertices {
#                 x: 358
#                 y: 411
#               }
#               vertices {
#                 x: 346
#                 y: 411
#               }
#             }
#             text: "l"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 359
#                 y: 338
#               }
#               vertices {
#                 x: 384
#                 y: 338
#               }
#               vertices {
#                 x: 384
#                 y: 411
#               }
#               vertices {
#                 x: 359
#                 y: 411
#               }
#             }
#             text: "v"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 385
#                 y: 339
#               }
#               vertices {
#                 x: 409
#                 y: 339
#               }
#               vertices {
#                 x: 409
#                 y: 412
#               }
#               vertices {
#                 x: 385
#                 y: 412
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: EOL_SURE_SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 410
#                 y: 339
#               }
#               vertices {
#                 x: 443
#                 y: 339
#               }
#               vertices {
#                 x: 443
#                 y: 412
#               }
#               vertices {
#                 x: 410
#                 y: 412
#               }
#             }
#             text: "y"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 32
#               y: 384
#             }
#             vertices {
#               x: 135
#               y: 388
#             }
#             vertices {
#               x: 133
#               y: 440
#             }
#             vertices {
#               x: 30
#               y: 436
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 32
#                 y: 385
#               }
#               vertices {
#                 x: 69
#                 y: 386
#               }
#               vertices {
#                 x: 67
#                 y: 437
#               }
#               vertices {
#                 x: 30
#                 y: 436
#               }
#             }
#             text: "w"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 70
#                 y: 386
#               }
#               vertices {
#                 x: 89
#                 y: 387
#               }
#               vertices {
#                 x: 87
#                 y: 438
#               }
#               vertices {
#                 x: 68
#                 y: 437
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 90
#                 y: 387
#               }
#               vertices {
#                 x: 99
#                 y: 387
#               }
#               vertices {
#                 x: 97
#                 y: 438
#               }
#               vertices {
#                 x: 88
#                 y: 438
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 100
#                 y: 387
#               }
#               vertices {
#                 x: 117
#                 y: 388
#               }
#               vertices {
#                 x: 115
#                 y: 439
#               }
#               vertices {
#                 x: 98
#                 y: 438
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 118
#                 y: 388
#               }
#               vertices {
#                 x: 135
#                 y: 389
#               }
#               vertices {
#                 x: 133
#                 y: 440
#               }
#               vertices {
#                 x: 116
#                 y: 439
#               }
#             }
#             text: "h"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 152
#               y: 389
#             }
#             vertices {
#               x: 233
#               y: 392
#             }
#             vertices {
#               x: 231
#               y: 437
#             }
#             vertices {
#               x: 150
#               y: 434
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 152
#                 y: 389
#               }
#               vertices {
#                 x: 175
#                 y: 390
#               }
#               vertices {
#                 x: 173
#                 y: 435
#               }
#               vertices {
#                 x: 150
#                 y: 434
#               }
#             }
#             text: "m"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 176
#                 y: 390
#               }
#               vertices {
#                 x: 215
#                 y: 391
#               }
#               vertices {
#                 x: 213
#                 y: 436
#               }
#               vertices {
#                 x: 174
#                 y: 435
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 216
#                 y: 391
#               }
#               vertices {
#                 x: 223
#                 y: 391
#               }
#               vertices {
#                 x: 221
#                 y: 436
#               }
#               vertices {
#                 x: 214
#                 y: 436
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 224
#                 y: 392
#               }
#               vertices {
#                 x: 233
#                 y: 392
#               }
#               vertices {
#                 x: 231
#                 y: 437
#               }
#               vertices {
#                 x: 222
#                 y: 437
#               }
#             }
#             text: "e"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 252
#               y: 392
#             }
#             vertices {
#               x: 335
#               y: 395
#             }
#             vertices {
#               x: 333
#               y: 441
#             }
#             vertices {
#               x: 250
#               y: 438
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 252
#                 y: 393
#               }
#               vertices {
#                 x: 273
#                 y: 394
#               }
#               vertices {
#                 x: 271
#                 y: 439
#               }
#               vertices {
#                 x: 250
#                 y: 438
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 274
#                 y: 393
#               }
#               vertices {
#                 x: 291
#                 y: 394
#               }
#               vertices {
#                 x: 289
#                 y: 439
#               }
#               vertices {
#                 x: 272
#                 y: 438
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 292
#                 y: 394
#               }
#               vertices {
#                 x: 321
#                 y: 395
#               }
#               vertices {
#                 x: 319
#                 y: 440
#               }
#               vertices {
#                 x: 290
#                 y: 439
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 322
#                 y: 395
#               }
#               vertices {
#                 x: 335
#                 y: 395
#               }
#               vertices {
#                 x: 333
#                 y: 440
#               }
#               vertices {
#                 x: 320
#                 y: 440
#               }
#             }
#             text: "n"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 349
#               y: 412
#             }
#             vertices {
#               x: 372
#               y: 413
#             }
#             vertices {
#               x: 371
#               y: 434
#             }
#             vertices {
#               x: 348
#               y: 433
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 349
#                 y: 412
#               }
#               vertices {
#                 x: 372
#                 y: 413
#               }
#               vertices {
#                 x: 371
#                 y: 434
#               }
#               vertices {
#                 x: 348
#                 y: 433
#               }
#             }
#             text: "a"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 388
#               y: 398
#             }
#             vertices {
#               x: 473
#               y: 401
#             }
#             vertices {
#               x: 471
#               y: 458
#             }
#             vertices {
#               x: 386
#               y: 455
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 388
#                 y: 398
#               }
#               vertices {
#                 x: 417
#                 y: 399
#               }
#               vertices {
#                 x: 415
#                 y: 456
#               }
#               vertices {
#                 x: 386
#                 y: 455
#               }
#             }
#             text: "c"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 418
#                 y: 399
#               }
#               vertices {
#                 x: 437
#                 y: 400
#               }
#               vertices {
#                 x: 435
#                 y: 457
#               }
#               vertices {
#                 x: 416
#                 y: 456
#               }
#             }
#             text: "\303\263"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 438
#                 y: 400
#               }
#               vertices {
#                 x: 447
#                 y: 400
#               }
#               vertices {
#                 x: 445
#                 y: 457
#               }
#               vertices {
#                 x: 436
#                 y: 457
#               }
#             }
#             text: "p"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 448
#                 y: 400
#               }
#               vertices {
#                 x: 465
#                 y: 401
#               }
#               vertices {
#                 x: 463
#                 y: 458
#               }
#               vertices {
#                 x: 446
#                 y: 457
#               }
#             }
#             text: "y"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 466
#                 y: 401
#               }
#               vertices {
#                 x: 473
#                 y: 401
#               }
#               vertices {
#                 x: 471
#                 y: 458
#               }
#               vertices {
#                 x: 464
#                 y: 458
#               }
#             }
#             text: "."
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "DURSH\nAn original y alvay\nworth more than a c\303\263py.\n"
# }

# %%
annotations = response.text_annotations
annotations   
if len(annotations) > 0:
    text = annotations[0].description
else:
    text = ''
#print('Extracted text {} from image ({} chars).'.format(text, len(text)))
text =format(text)

# %%
annotations
# Out:
# [locale: "en"
# description: "DURSH\nAn original y alvay\nworth more than a c\303\263py.\n"
# bounding_poly {
#   vertices {
#     x: 25
#     y: 197
#   }
#   vertices {
#     x: 490
#     y: 197
#   }
#   vertices {
#     x: 490
#     y: 458
#   }
#   vertices {
#     x: 25
#     y: 458
#   }
# }
# , description: "DURSH"
# bounding_poly {
#   vertices {
#     x: 30
#     y: 197
#   }
#   vertices {
#     x: 490
#     y: 214
#   }
#   vertices {
#     x: 485
#     y: 343
#   }
#   vertices {
#     x: 25
#     y: 326
#   }
# }
# , description: "An"
# bounding_poly {
#   vertices {
#     x: 71
#     y: 342
#   }
#   vertices {
#     x: 127
#     y: 342
#   }
#   vertices {
#     x: 127
#     y: 410
#   }
#   vertices {
#     x: 71
#     y: 410
#   }
# }
# , description: "original"
# bounding_poly {
#   vertices {
#     x: 137
#     y: 338
#   }
#   vertices {
#     x: 280
#     y: 339
#   }
#   vertices {
#     x: 280
#     y: 412
#   }
#   vertices {
#     x: 137
#     y: 411
#   }
# }
# , description: "y"
# bounding_poly {
#   vertices {
#     x: 289
#     y: 347
#   }
#   vertices {
#     x: 311
#     y: 347
#   }
#   vertices {
#     x: 311
#     y: 398
#   }
#   vertices {
#     x: 289
#     y: 398
#   }
# }
# , description: "alvay"
# bounding_poly {
#   vertices {
#     x: 326
#     y: 338
#   }
#   vertices {
#     x: 443
#     y: 339
#   }
#   vertices {
#     x: 443
#     y: 413
#   }
#   vertices {
#     x: 326
#     y: 412
#   }
# }
# , description: "worth"
# bounding_poly {
#   vertices {
#     x: 32
#     y: 384
#   }
#   vertices {
#     x: 135
#     y: 388
#   }
#   vertices {
#     x: 133
#     y: 440
#   }
#   vertices {
#     x: 30
#     y: 436
#   }
# }
# , description: "more"
# bounding_poly {
#   vertices {
#     x: 152
#     y: 389
#   }
#   vertices {
#     x: 233
#     y: 392
#   }
#   vertices {
#     x: 231
#     y: 437
#   }
#   vertices {
#     x: 150
#     y: 434
#   }
# }
# , description: "than"
# bounding_poly {
#   vertices {
#     x: 252
#     y: 392
#   }
#   vertices {
#     x: 335
#     y: 395
#   }
#   vertices {
#     x: 333
#     y: 441
#   }
#   vertices {
#     x: 250
#     y: 438
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 349
#     y: 412
#   }
#   vertices {
#     x: 372
#     y: 413
#   }
#   vertices {
#     x: 371
#     y: 434
#   }
#   vertices {
#     x: 348
#     y: 433
#   }
# }
# , description: "c\303\263py."
# bounding_poly {
#   vertices {
#     x: 388
#     y: 398
#   }
#   vertices {
#     x: 473
#     y: 401
#   }
#   vertices {
#     x: 471
#     y: 458
#   }
#   vertices {
#     x: 386
#     y: 455
#   }
# }
# ]

# %%
#Creating a function to detect text
client = vision.ImageAnnotatorClient()
import io
def detect_text(path):
    with io.open(path, 'rb') as image_file:
        content = image_file.read()
    image = vision.types.Image(content=content)
    response = client.text_detection(image=image)
    annotations = response.text_annotations
    if len(annotations) > 0:
        text = annotations[0].description
    else:
        text = ''
    return (text)

# %%
print(detect_text('C:/Users/kanum/Desktop/Data_Science_Everyday/Hackathons/Love is Love/Dataset/Test803.jpg'))
# Out:
# BE
# OURSER
# An original iy alvay
# worth more than
# cópy.
# a

# %%
image
# Out:
# content: "\377\330\377\340\000\020JFIF\000\001\001\001\000d\000d\000\000\377\333\000C\000\010\006\006\007\006\005\010\007\007\007\t\t\010\n\014\024\r\014\013\013\014\031\022\023\017\024\035\032\037\036\035\032\034\034 $.\' \",#\034\034(7),01444\037\'9=82<.342\377\333\000C\001\t\t\t\014\013\014\030\r\r\0302!\034!22222222222222222222222222222222222222222222222222\377\300\000\021\010\000\250\000\354\003\001\"\000\002\021\001\003\021\001\377\304\000\037\000\000\001\005\001\001\001\001\001\001\000\000\000\000\000\000\000\000\001\002\003\004\005\006\007\010\t\n\013\377\304\000\265\020\000\002\001\003\003\002\004\003\005\005\004\004\000\000\001}\001\002\003\000\004\021\005\022!1A\006\023Qa\007\"q\0242\201\221\241\010#B\261\301\025R\321\360$3br\202\t\n\026\027\030\031\032%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\203\204\205\206\207\210\211\212\222\223\224\225\226\227\230\231\232\242\243\244\245\246\247\250\251\252\262\263\264\265\266\267\270\271\272\302\303\304\305\306\307\310\311\312\322\323\324\325\326\327\330\331\332\341\342\343\344\345\346\347\350\351\352\361\362\363\364\365\366\367\370\371\372\377\304\000\037\001\000\003\001\001\001\001\001\001\001\001\001\000\000\000\000\000\000\001\002\003\004\005\006\007\010\t\n\013\377\304\000\265\021\000\002\001\002\004\004\003\004\007\005\004\004\000\001\002w\000\001\002\003\021\004\005!1\006\022AQ\007aq\023\"2\201\010\024B\221\241\261\301\t#3R\360\025br\321\n\026$4\341%\361\027\030\031\032&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\202\203\204\205\206\207\210\211\212\222\223\224\225\226\227\230\231\232\242\243\244\245\246\247\250\251\252\262\263\264\265\266\267\270\271\272\302\303\304\305\306\307\310\311\312\322\323\324\325\326\327\330\331\332\342\343\344\345\346\347\350\351\352\362\363\364\365\366\367\370\371\372\377\332\000\014\003\001\000\002\021\003\021\000?\000\366\314\2322h\242\274\253\233\006M\0314QE\3002h\311\242\212.\001\223FM\024Qp\014\2322h\315\024\\\003&\214\232(\242\340\0314d\321E\027\000\311\243&\212(\270\006M\0314QE\3002h\311\242\212.\001\223FM\024Qp\014\2322h\242\213\200d\321\223E\024\\\003&\214\232(\242\340\0314d\321E\027\000\242\212(\000\242\212(\000\242\212(\000\243p\365\254\335rsm\246H\352\345\017\000\032\247\036\237\230\222Y/%\303\000ylVU\353\302\215\234\372\224\242\336\246\355\025\200\361^Z\251\226\316\344\314\253\311F9\315i\351\272\202_\333\357Q\265\301\303)\352\r:5\241Y^\037\360A\305\242\355\024\224\271\255\t\n(\315\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\000QE\024\001\205\342\304/\241I\216\314\017\353Uu\t\021l\354|\342DG\033\277*\321\361\022\027\321g\030\3503O\265\215&\323\340\022\"\260\330:\212\341\307\325T\2359\265sX\374&~\230\243\373FSj[\354\245G^\231\254\315N\356\346\303\304Q\333\330\262\247\332\027-\221\320\212\336\273\324-\254#\332\270.~\354i\324\232\347\345\264\237\373F\326\366\350bYX\341\177\272=+\032\022\251)\317\023nT\223\374\213\215\257\357\027\204\332\336\177\343\352/\373\346\236\332\206\261\021W\304R(\352\203\251\247\334\334\013x\3672\263\177\2723Y\262k\212\235-.\033\350\265\305O0\306\316\322\215\254k\354\342\313\366\376!\272\227[\202\316Ko*9\0019\'\232\351\253\201\323\257\037S\361U\253\013ic\021!$\270\305w\325\364\024\345)R\214\246\265g=X\250\312\310Z(\242\231\220QE\024\300(\242\212\000(\242\212\000(\242\212\000(\242\212\000(\242\212\000(\242\212\000(\242\253_\\\275\255\244\223$fFQ\235\243\275\026\273\260\026h\2568x\306\341\206V\313?V\255\r#\304\321\337\\\033{\204\020J~\350\'\203G\273~^\246\216\215H\256kht\024U=KQ\207L\263{\231\233\345Q\300\365\256f?\031\334\310\233\376\303\200ze\250zF\354!NR\326(\351uu\r\245N\017\367j\033P\037L\215Km\005\000\315dE\255\334j\272e\341{o-\0218l\3654\373\247\037\330\026\305\230\252\035\273\210=\253\2030\247\317\354\343~\245E5t\310\227I\223K\231\357m\3447\004\034\262\311\311\307\265K\250\335%\344\272|\311\321\211\343\322\246\323\202\375\266D\267v{b\234\2269\031\254wb\232\300\200\177\253IN\337\312\245Nj5h\315\336\321\320\250\253\3113^y\341\267\217|\316\02 ...

# %%
#Implementing Google API on entire images
#Performing OCR on base image
import cv2
import os
import glob
img_dir = 'C:/Users/kanum/Desktop/Data_Science_Everyday/Hackathons/Love is Love/Dataset' # Enter Directory of all images 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = []
filename = []
for f1 in files:
    file = os.path.basename(f1)
    filename.append(file)
    img = cv2.imread(f1)
    text = detect_text(f1)
    data.append(text)

# %%
import pandas as pd
df = pd.DataFrame()
df['Filename'] = filename
df['text'] = data
#print(df['text'].value_counts())
df.head(5)
# Out:
#        Filename                                               text
# 0   Test100.jpg                             Married\nwith\nPRIDF\n
# 1  Test1001.jpg  When people ask\nwhat I see in you,\nI just sm...
# 2  Test1012.jpg  LOVE\nIS TOO BEAUTIFUL\nTO BE HIDDEN\nIN THE C...
# 3  Test1022.jpg  LOVE\nlov\netty\nis\nQ123RF\ndreaRF®\n@123RF\n...
# 4   Test103.jpg                    160 YEARS OF ATLANTIC STORIES\n

# %%
#Sentiment Analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
#Applying on a simple text
a = df['text'][1]
analyzer.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.7717}

# %%
#Adding scores dictionary to the input data
df['sentiment'] = df['text'].apply(lambda text: analyzer.polarity_scores(text))
df.head()
# Out:
#        Filename                                               text  \
# 0   Test100.jpg                             Married\nwith\nPRIDF\n
# 1  Test1001.jpg  When people ask\nwhat I see in you,\nI just sm...
# 2  Test1012.jpg  LOVE\nIS TOO BEAUTIFUL\nTO BE HIDDEN\nIN THE C...
# 3  Test1022.jpg  LOVE\nlov\netty\nis\nQ123RF\ndreaRF®\n@123RF\n...
# 4   Test103.jpg                    160 YEARS OF ATLANTIC STORIES\n
#
#                                            sentiment
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'comp...
# 2  {'neg': 0.0, 'neu': 0.497, 'pos': 0.503, 'comp...
# 3  {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compou...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %%
import re as re
#Cleaned text
def clean_text(text):
    text = text.lower()
    text = re.sub(r"\+", " plus ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\?", " ? ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r"\s{2,}", " ", text)
    # example to not remove numbers
    return text
    #return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', text).split())

df["text"] = df['text'].apply(lambda x: clean_text(x))

def sentiment_scores(text): 
  
    # Create a SentimentIntensityAnalyzer object. 
    analyzer_obj = SentimentIntensityAnalyzer() 
  
    # polarity_scores method of SentimentIntensityAnalyzer 
    # oject gives a sentiment dictionary. 
    # which contains pos, neg, neu, and compound scores. 
    sentiment_dict = analyzer_obj.polarity_scores(text) 
      
    if sentiment_dict['compound'] > 0:
        return 'Positive'
    elif sentiment_dict['compound'] < 0:
        return 'Negative'
    else:
        return 'Random'

df["Category"] = df["text"].apply(lambda x: sentiment_scores(x))

print(df.head(5))
# Out:
#        Filename                                               text  \
# 0   Test100.jpg                                 married with pridf
# 1  Test1001.jpg  when people ask what i see in you i just smile...
# 2  Test1012.jpg   love is too beautiful to be hidden in the closet
# 3  Test1022.jpg              love lov etty is q123rf drearf o123rf
# 4   Test103.jpg                      160 years of atlantic stories
#
#                                            sentiment  Category
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    Random
# 1  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'comp...  Positive
# 2  {'neg': 0.0, 'neu': 0.497, 'pos': 0.503, 'comp...  Positive
# 3  {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compou...  Positive
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    Random

# %%
df.to_csv("df2.csv",index = False)

# %%
submission = df.drop(['text','sentiment'],axis = 1)
submission
# Out:
#          Filename  Category
# 0     Test100.jpg    Random
# 1    Test1001.jpg  Positive
# 2    Test1012.jpg  Positive
# 3    Test1022.jpg  Positive
# 4     Test103.jpg    Random
# ..            ...       ...
# 234   Test945.jpg  Negative
# 235   Test946.jpg  Negative
# 236   Test957.jpg  Positive
# 237   Test979.jpg  Positive
# 238   Test993.jpg  Positive
#
# [239 rows x 2 columns]

# %%
submission.to_csv("submission_g_api_clean_text.csv",index = False)
